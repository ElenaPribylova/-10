# %% [markdown]
# <a href="https://colab.research.google.com/github/ElenaPribylova/-10/blob/main/%D0%9A%D0%B5%D0%B9%D1%81_%D0%B0%D0%B2%D1%82%D0%BE%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D1%80%D0%BA%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **1 кейс**
#
# **Система автопроверки**

# %% [markdown]
# **Важно**
#
# Перед началом решения выполните следующую ячейку, чтобы загрузить два файла - эталонный код и код пользователя.

# %%
# !wget https://gist.github.com/Vs8th/aafed81d81678c807a3ad3dbf93588b2/raw/user.py

# !wget https://gist.github.com/Vs8th/95f7897019a4213c76e5b65234d31e30/raw/etalon.py

# !wget https://gist.github.com/Vs8th/59f797dfbd33f9a4be1e5ed43bb42f4d/raw/res_cor.txt
# Out:
# --2025-12-06 12:56:33--  https://gist.github.com/Vs8th/aafed81d81678c807a3ad3dbf93588b2/raw/user.py
# Resolving gist.github.com (gist.github.com)... 140.82.112.3
# Connecting to gist.github.com (gist.github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/aafed81d81678c807a3ad3dbf93588b2/raw/user.py [following]
# --2025-12-06 12:56:33--  https://gist.githubusercontent.com/Vs8th/aafed81d81678c807a3ad3dbf93588b2/raw/user.py
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 106 [text/plain]
# Saving to: ‘user.py’
#
# user.py             100%[===================>]     106  --.-KB/s    in 0s
#
# 2025-12-06 12:56:33 (4.08 MB/s) - ‘user.py’ saved [106/106]
#
# --2025-12-06 12:56:33--  https://gist.github.com/Vs8th/95f7897019a4213c76e5b65234d31e30/raw/etalon.py
# Resolving gist.github.com (gist.github.com)... 140.82.113.3
# Connecting to gist.github.com (gist.github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/95f7897019a4213c76e5b65234d31e30/raw/etalon.py [following]
# --2025-12-06 12:56:34--  https://gist.githubusercontent.com/Vs8th/95f7897019a4213c76e5b65234d31e30/raw/etalon.py
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31 [text/plain]
# Saving to: ‘etalon.py’
#
# etalon.py           100%[===================>]      31  --.-KB/s    in 0s
#
# 2025-12-06 12:56:34 (922 KB/s) - ‘etalon.py’ saved [31/31]
#
# --2025-12-06 12:56:34--  https://gist.github.com/Vs8th/59f797dfbd33f9a4be1e5ed43bb42f4d/raw/res_cor.txt
# Resolving gist.github.com (gist.github.com)... 140.82.113.3
# Connecting to gist.github.com (gist.github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/59f797dfbd33f9a4be1e5ed43bb42f4d/raw/res_cor.txt [following]
# --2025-12-06 12:56:34--  https://gist.githubusercontent.com/Vs8th/59f797dfbd33f9a4be1e5ed43bb42f4d/raw/res_cor.txt
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 355 [text/plain]
# Saving to: ‘res_cor.txt’
#
# res_cor.txt         100%[===================>]     355  --.-KB/s    in 0s
#
# 2025-12-06 12:56:34 (17.3 MB/s) - ‘res_cor.txt’ saved [355/355]

# %% [markdown]
# Давайте сразу посмотрим с каким кодом мы имеем дело.

# %%
with open('etalon.py', 'r') as f:
    lines = f.readlines()

lines
# Out:
# ['def add(a, b):\n', '    return a + b']

# %%
with open('user.py', 'r') as f:
    lines2 = f.readlines()

lines2
# Out:
# ['def add_numbers(a, b):\n',
#  '    return a - b  # Ошибка: нужно сложить, а не вычесть']

# %% [markdown]
# ### **Решения**

# %% [markdown]
# #### **Задача 1**
#
# Задача не из легких, поэтому начнем по шагам. Для начала напишите функцию, которая прочтет эталонный код и код пользователя из `.py` файлов, выполнит их и вернет соответствующие результаты.

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
import importlib

def run_tests(standard_code, user_code, test_cases, output_file):
    with open(output_file, 'w') as f:
        for test in test_cases:
            if isinstance(test, (int, float)):
                test = (test,)
            try:
                standard_result = standard_code(*test)
            except Exception as e:
                f.write("Ошибка при выполнении эталонного кода: {}\n".format(e))
                return

            try:
                user_result = user_code(*test)
            except Exception as e:
                f.write("Ошибка при выполнении кода пользователя: {}\n".format(e))
                return

            if standard_result == user_result:
                f.write("Тест пройден\n")
            else:
                f.write("Тест не пройден\n")
                f.write("Ожидаемый результат: {}\n".format(standard_result))
                f.write("Результат пользователя: {}\n".format(user_result))


# Чтение кодов из файлов
standard_module = importlib.import_module('etalon')
user_module = importlib.import_module('user')

test_cases = [(1, 2), (3, 4), (5, 6)]
output_file = 'output.txt'
run_tests(standard_module.add, user_module.add_numbers, test_cases, output_file)

# %% [markdown]
# ✏️ ✏️ ✏️
#
# **Проверка**
#
# Чтобы проверить свое решение, запустите код в следующих ячейках

# %%
with open('output.txt', 'r') as file1:
    res1 = file1.read()

with open('res_cor.txt', 'r') as file2:
    res2 = file2.read()

try:
    assert res1== res2
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!

# %% [markdown]
# #### **Задача 2**
#
# Теперь давайте двигаться дальше. Нужно добавить проверку на вредоносный код. Напишите отдельную функцию - `check_for_malicious_code`, которую мы будем вызывать перед проверкой кода.

# %%
# !wget https://gist.github.com/Vs8th/9f6a2c73c755cfcc088c7835ec4fb2c0/raw/user_malicious.py
# Out:
# --2025-12-06 13:05:10--  https://gist.github.com/Vs8th/9f6a2c73c755cfcc088c7835ec4fb2c0/raw/user_malicious.py
# Resolving gist.github.com (gist.github.com)... 140.82.113.3
# Connecting to gist.github.com (gist.github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/9f6a2c73c755cfcc088c7835ec4fb2c0/raw/user_malicious.py [following]
# --2025-12-06 13:05:10--  https://gist.githubusercontent.com/Vs8th/9f6a2c73c755cfcc088c7835ec4fb2c0/raw/user_malicious.py
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117 [text/plain]
# Saving to: ‘user_malicious.py’
#
# user_malicious.py   100%[===================>]     117  --.-KB/s    in 0s
#
# 2025-12-06 13:05:10 (4.87 MB/s) - ‘user_malicious.py’ saved [117/117]

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
import ast
import importlib
import inspect

FORBIDDEN_NAMES = ['eval', 'exec']

def check_for_malicious_code(code, output_file):
    try:
        tree = ast.parse(code)
        for node in ast.walk(tree):
            if isinstance(node, ast.Attribute) and node.attr in FORBIDDEN_NAMES:
                raise ValueError("Код содержит запрещенный атрибут: {}".format(node.attr))
            elif isinstance(node, ast.Call) and isinstance(node.func, ast.Name) and node.func.id == 'eval':
                raise ValueError("Код содержит вызов eval()")
    except SyntaxError as e:
        with open(output_file, 'w') as f:
            f.write("Код содержит синтаксическую ошибку: {}\n".format(e.msg))
        return str(e)
    except ValueError as e:
        with open(output_file, 'w') as f:
            f.write("Код содержит вредоносные элементы: {}\n".format(str(e)))
        return str(e)

    with open(output_file, 'w') as f:
        f.write("Код не содержит вредоносные элементы.\n")

def run_tests(standard_code, user_code, test_cases, output_file):
    with open(output_file, 'w') as f:
        for test in test_cases:
            if isinstance(test, (int, float)):
                test = (test,)
            try:
                standard_result = standard_code(*test)
            except Exception as e:
                f.write("Ошибка при выполнении эталонного кода: {}\n".format(e))
                return

            try:
                user_result = user_code(*test)
            except Exception as e:
                f.write("Ошибка при выполнении кода пользователя: {}\n".format(e))
                return

            if standard_result == user_result:
                f.write("Тест пройден\n")
            else:
                f.write("Тест не пройден\n")
                f.write("Ожидаемый результат: {}\n".format(standard_result))
                f.write("Результат пользователя: {}\n".format(user_result))

# Чтение кодов из файлов
standard_module = importlib.import_module('etalon')
user_module = importlib.import_module('user_malicious')

test_cases = [(1, 2), (3, 4), (5, 6)]
output_file = 'output2.txt'
# Проверка на вредоносный код
malicious_code_message = check_for_malicious_code(inspect.getsource(user_module), output_file)
if malicious_code_message:
    with open(output_file, 'w') as f:
        f.write("Ошибка при проверке модуля user_malicious:\n")
        f.write(malicious_code_message)
else:
    run_tests(standard_module.add, user_module.add_numbers, test_cases, output_file)

# %% [markdown]
# ✏️ ✏️ ✏️
#
# **Проверка**
#
# Чтобы проверить свое решение, запустите код в следующих ячейках

# %%
# Здесь будет скачиваться файл с эталонным ответом

# !wget https://gist.github.com/Vs8th/5197125c5ef1e1b34b7d73adccdaf4bb/raw/cor_output_2.txt
# Out:
# --2025-12-06 13:08:46--  https://gist.github.com/Vs8th/5197125c5ef1e1b34b7d73adccdaf4bb/raw/cor_output_2.txt
# Resolving gist.github.com (gist.github.com)... 140.82.114.3
# Connecting to gist.github.com (gist.github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/5197125c5ef1e1b34b7d73adccdaf4bb/raw/cor_output_2.txt [following]
# --2025-12-06 13:08:46--  https://gist.githubusercontent.com/Vs8th/5197125c5ef1e1b34b7d73adccdaf4bb/raw/cor_output_2.txt
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 107 [text/plain]
# Saving to: ‘cor_output_2.txt’
#
# cor_output_2.txt    100%[===================>]     107  --.-KB/s    in 0s
#
# 2025-12-06 13:08:47 (2.59 MB/s) - ‘cor_output_2.txt’ saved [107/107]

# %%
with open('output2.txt', 'r') as file1:
    res1 = file1.read()

with open('cor_output_2.txt', 'r') as file2:
    res2 = file2.read()

try:
    assert res1== res2
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!

# %% [markdown]
# #### **Задача 3**
#
# Движемся дальше - последнее, что нам нужно проверить - время выполнения. Если время выполнения превышает 5 секунд, уведомите об этом пользователя и остановите выполнение проверки.

# %%
# !wget https://gist.github.com/Vs8th/4aba49489a8b0843ef85c4a1a93f923d/raw/user_inf.py
# Out:
# --2025-12-06 13:08:59--  https://gist.github.com/Vs8th/4aba49489a8b0843ef85c4a1a93f923d/raw/user_inf.py
# Resolving gist.github.com (gist.github.com)... 140.82.114.3
# Connecting to gist.github.com (gist.github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/4aba49489a8b0843ef85c4a1a93f923d/raw/user_inf.py [following]
# --2025-12-06 13:08:59--  https://gist.githubusercontent.com/Vs8th/4aba49489a8b0843ef85c4a1a93f923d/raw/user_inf.py
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55 [text/plain]
# Saving to: ‘user_inf.py’
#
# user_inf.py         100%[===================>]      55  --.-KB/s    in 0s
#
# 2025-12-06 13:08:59 (2.73 MB/s) - ‘user_inf.py’ saved [55/55]

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
import ast
import importlib
import inspect
import time

FORBIDDEN_NAMES = ['eval', 'exec']

def check_for_malicious_code(code, output_file):
    try:
        tree = ast.parse(code)
        for node in ast.walk(tree):
            if isinstance(node, ast.Attribute) and node.attr in FORBIDDEN_NAMES:
                raise ValueError("Код содержит запрещенный атрибут: {}".format(node.attr))
            elif isinstance(node, ast.Call) and isinstance(node.func, ast.Name) and node.func.id == 'eval':
                raise ValueError("Код содержит вызов eval()")
    except SyntaxError as e:
        with open(output_file, 'w') as f:
            f.write("Код содержит синтаксическую ошибку: {}\n".format(e.msg))
        return str(e)
    except ValueError as e:
        with open(output_file, 'w') as f:
            f.write("Код содержит вредоносные элементы: {}\n".format(str(e)))
        return str(e)

    with open(output_file, 'w') as f:
        f.write("Код не содержит вредоносные элементы.\n")

import multiprocessing

def run_tests(standard_code, user_code, test_cases, output_file):
    with open(output_file, 'w') as f:
        for test in test_cases:
            if isinstance(test, (int, float)):
                test = (test,)
            try:
                standard_result = standard_code(*test)
            except Exception as e:
                f.write("Ошибка при выполнении эталонного кода: {}\n".format(e))
                return

            try:
                process = multiprocessing.Process(target=user_code, args=test)
                start_time = time.time()
                process.start()
                process.join(timeout=5)
                if process.is_alive():
                    process.terminate()
                    raise TimeoutError("Превышено время выполнения.")
                execution_time = time.time() - start_time
            except TimeoutError as e:
                f.write("Предупреждение: время выполнения превышает 5 секунд.")
                return
            except Exception as e:
                f.write("Ошибка при выполнении кода пользователя: {}\n".format(e))
                return

            if standard_result == user_result:
                f.write("Тест пройден\n")
            else:
                f.write("Тест не пройден\n")
                f.write("Ожидаемый результат: {}\n".format(standard_result))
                f.write("Результат пользователя: {}\n".format(user_result))


# Чтение кодов из файлов
standard_module = importlib.import_module('etalon')
user_module = importlib.import_module('user_inf')

test_cases = [(1, 2), (3, 4), (5, 6)]
output_file = 'output3.txt'
# Проверка на вредоносный код
malicious_code_message = check_for_malicious_code(inspect.getsource(user_module), output_file)
if malicious_code_message:
    with open(output_file, 'w') as f:
        f.write("Ошибка при проверке модуля user_malicious:\n")
        f.write(malicious_code_message)
else:
    run_tests(standard_module.add, user_module.add_numbers, test_cases, output_file)

# %% [markdown]
# ✏️ ✏️ ✏️
#
# **Проверка**
#
# Чтобы проверить свое решение, запустите код в следующих ячейках

# %%
# Здесь будет скачиваться файл с эталонным ответом

# !wget https://gist.github.com/Vs8th/cfcafbd2cd46e8905555b02eae78406e/raw/cor_res_3.txt
# Out:
# --2025-12-06 13:09:27--  https://gist.github.com/Vs8th/cfcafbd2cd46e8905555b02eae78406e/raw/cor_res_3.txt
# Resolving gist.github.com (gist.github.com)... 140.82.113.4
# Connecting to gist.github.com (gist.github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/cfcafbd2cd46e8905555b02eae78406e/raw/cor_res_3.txt [following]
# --2025-12-06 13:09:27--  https://gist.githubusercontent.com/Vs8th/cfcafbd2cd46e8905555b02eae78406e/raw/cor_res_3.txt
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 96 [text/plain]
# Saving to: ‘cor_res_3.txt’
#
# cor_res_3.txt       100%[===================>]      96  --.-KB/s    in 0s
#
# 2025-12-06 13:09:28 (2.17 MB/s) - ‘cor_res_3.txt’ saved [96/96]

# %%
with open('output3.txt', 'r') as file1:
    res1 = file1.read()

with open('cor_res_3.txt', 'r') as file2:
    res2 = file2.read()

try:
    assert res1== res2
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!
